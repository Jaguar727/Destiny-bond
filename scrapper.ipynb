# %%
import bs4
import urllib.request as urllib_request
import pandas as pd
import pymongo
from pymongo import MongoClient
from bs4 import BeautifulSoup
from urllib.request import urlopen, Request
from typing import List, NamedTuple

# %%
# client = MongoClient(MONGO_DB_CLIENT_URI)
# db = client.pokedex_vue
# pokemon_collection = db.pokemon

# %%
response = urlopen('https://www.serebii.net/pokemon/nationalpokedex.shtml')
html = response.read().decode('latin-1')
soup = BeautifulSoup(html, 'html.parser')

# %%
pokedex = soup.find('table', {'class' : 'dextable'}).findAll('tr',recursive=False)

allPkm = []

class Pokemon(NamedTuple):
    id: str
    name: str
    icon: str
    types: List[str]
    abilities: List[str]
    hp: int
    attack: int
    defense: int
    sp_attack: int
    sp_defense: int
    speed: int

for row in pokedex[2:]:
    pokemon = {}
    pkm = row.findAll('td', {'class': 'fooinfo'})

    pokemon['id']  = pkm[0].getText()
    pokemon['id'] = pokemon['id'].replace('\t', '').replace('\n', '').replace('\r', '')
    pokemon['icon'] = pkm[1].find('img')['src']
    pokemon['name'] = pkm[2].find('a').getText()
    pokemon['types'] = pkm[3].findAll('img')
    cont = 0

    for type in pokemon['types']:
        pokemon['types'][cont] = type['src'][17:-4]
        cont = cont + 1
        
    
    cont = 0
    pokemon['abilities'] = pkm[4].findAll('a')
    
    for ability in pokemon['abilities']:
        pokemon['abilities'][cont] = ability.getText()
        cont = cont + 1
    
    pokemon['hp']  = pkm[5].getText()
    pokemon['attack']  = pkm[6].getText()
    pokemon['defense']  = pkm[7].getText()
    pokemon['sp_attack']  = pkm[8].getText()
    pokemon['sp_defense']  = pkm[9].getText()
    pokemon['speed']  = pkm[10].getText()

    pokemon_data = Pokemon(
        id = pokemon['id'],
        name = pokemon['name'],
        icon = pokemon['icon'],
        types = pokemon['types'],
        abilities = pokemon['abilities'],
        hp = pokemon['hp'],
        attack = pokemon['attack'],
        defense = pokemon['defense'],
        sp_attack = pokemon['sp_attack'],
        sp_defense = pokemon['sp_defense'],
        speed = pokemon['speed'],
    )
    
    # pokemon_collection.insert_one({
    #     "id": pokemon_data.id,
    #     "name": pokemon_data.name,
    #     "icon": pokemon_data.icon,
    #     "types": pokemon_data.types,
    #     "abilities": pokemon_data.abilities,
    #     "hp": int(pokemon_data.hp),
    #     "attack": int(pokemon_data.attack),
    #     "defense": int(pokemon_data.defense),
    #     "sp_attack": int(pokemon_data.sp_attack),
    #     "sp_defense": int(pokemon_data.sp_defense),
    #     "speed": int(pokemon_data.speed),
    # })

    allPkm.append(pokemon_data)

print(allPkm)
# dataset = pd.DataFrame(allPkm)
# dataset.to_json('./data.json', orient = 'split',index = False)
# Out:
# [Pokemon(id='#001', name='Bulbasaur', icon='/pokedex-swsh/icon/001.png', types=['grass', 'poison'], abilities=['Overgrow', 'Chlorophyll'], hp='45', attack='49', defense='49', sp_attack='65', sp_defense='65', speed='45'), Pokemon(id='#002', name='Ivysaur', icon='/pokedex-swsh/icon/002.png', types=['grass', 'poison'], abilities=['Overgrow', 'Chlorophyll'], hp='60', attack='62', defense='63', sp_attack='80', sp_defense='80', speed='60'), Pokemon(id='#003', name='Venusaur', icon='/pokedex-swsh/icon/003.png', types=['grass', 'poison'], abilities=['Overgrow', 'Chlorophyll'], hp='80', attack='82', defense='83', sp_attack='100', sp_defense='100', speed='80'), Pokemon(id='#004', name='Charmander', icon='/pokedex-swsh/icon/004.png', types=['fire'], abilities=['Blaze', 'Solar Power'], hp='39', attack='52', defense='43', sp_attack='60', sp_defense='50', speed='65'), Pokemon(id='#005', name='Charmeleon', icon='/pokedex-swsh/icon/005.png', types=['fire'], abilities=['Blaze', 'Solar Power'], hp='58', attack='64', defense='58', sp_attack='80', sp_defense='65', speed='80'), Pokemon(id='#006', name='Charizard', icon='/pokedex-swsh/icon/006.png', types=['fire', 'flying'], abilities=['Blaze', 'Solar Power'], hp='78', attack='84', defense='78', sp_attack='109', sp_defense='85', speed='100'), Pokemon(id='#007', name='Squirtle', icon='/pokedex-swsh/icon/007.png', types=['water'], abilities=['Torrent', 'Rain Dish'], hp='44', attack='48', defense='65', sp_attack='50', sp_defense='64', speed='43'), Pokemon(id='#008', name='Wartortle', icon='/pokedex-swsh/icon/008.png', types=['water'], abilities=['Torrent', 'Rain Dish'], hp='59', attack='63', defense='80', sp_attack='65', sp_defense='80', speed='58'), Pokemon(id='#009', name='Blastoise', icon='/pokedex-swsh/icon/009.png', types=['water'], abilities=['Torrent', 'Rain Dish'], hp='79', attack='83', defense='100', sp_attack='85', sp_defense='105', speed='78'), Pokemon(id='#010', name='Caterpie', icon='/pokedex-swsh/icon/010.png', types=['bug'], abilities=['Shield Dust', 'Run Away'], hp='45', attack='30', defense='35', sp_attack='20', sp_defense='20', speed='45'), Pokemon(id='#011', name='Metapod', icon='/pokedex-swsh/icon/011.png', types=['bug'], abilities=['Shed Skin'], hp='50', attack='20', defense='55', sp_attack='25', sp_defense='25', speed='30'), Pokemon(id='#012', name='Butterfree', icon='/pokedex-swsh/icon/012.png', types=['bug', 'flying'], abilities=['Compoundeyes', 'Tinted Lens'], hp='60', attack='45', defense='50', sp_attack='90', sp_defense='80', speed='70'), Pokemon(id='#013', name='Weedle', icon='/pokedex-swsh/icon/013.png', types=['bug', 'poison'], abilities=['Shield Dust', 'Run Away'], hp='40', attack='35', defense='30', sp_attack='20', sp_defense='20', speed='50'), Pokemon(id='#014', name='Kakuna', icon='/pokedex-swsh/icon/014.png', types=['bug', 'poison'], abilities=['Shed Skin'], hp='45', attack='25', defense='50', sp_attack='25', sp_defense='25', speed='35'), Pokemon(id='#015', name='Beedrill', icon='/pokedex-swsh/icon/015.png', types=['bug', 'poison'], abilities=['Swarm', 'Sniper'], hp='65', attack='90', defense='40', sp_attack='45', sp_defense='80', speed='75'), Pokemon(id='#016', name='Pidgey', icon='/pokedex-swsh/icon/016.png', types=['normal', 'flying'], abilities=['Keen Eye', 'Tangled Feet', 'Big Pecks'], hp='40', attack='45', defense='40', sp_attack='35', sp_defense='35', speed='56'), Pokemon(id='#017', name='Pidgeotto', icon='/pokedex-swsh/icon/017.png', types=['normal', 'flying'], abilities=['Keen Eye', 'Tangled Feet', 'Big Pecks'], hp='63', attack='60', defense='55', sp_attack='50', sp_defense='50', speed='71'), Pokemon(id='#018', name='Pidgeot', icon='/pokedex-swsh/icon/018.png', types=['normal', 'flying'], abilities=['Keen Eye', 'Tangled Feet', 'Big Pecks'], hp='83', attack='80', defense='75', sp_attack='70', sp_defense='70', speed='101'), Pokemon(id='#019', name='Rattata', icon='/pokedex-swsh/icon/019.png', types=['normal'], abilities=['Run Away', 'Guts', 'Hustle'], hp='30', ...
